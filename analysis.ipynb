# %%
import sqlite3
import pandas as pd

# Connect to the SQLite database
conn = sqlite3.connect("trading.db")

# Read the tables into pandas DataFrames
orders_df = pd.read_sql("SELECT * FROM orders", conn)
positions_df = pd.read_sql("SELECT * FROM positions", conn)
fills_df = pd.read_sql("SELECT * FROM fills", conn)
portfolio_df = pd.read_sql("SELECT * FROM portfolio_state", conn)
daily_df = pd.read_sql("SELECT * FROM daily_metrics", conn)
metrics_df = pd.read_sql("SELECT * FROM strategy_metrics", conn)
trade_logs_df = pd.read_sql("SELECT * FROM trades", conn)



# Close the connection
conn.close()

# %%
orders_df.columns
# Out:
# Index(['order_id', 'symbol', 'side', 'quantity', 'order_type', 'price',
#        'stop_price', 'status', 'filled_quantity', 'average_price', 'timestamp',
#        'strategy_id', 'stop_loss', 'take_profit', 'created_at'],
#       dtype='object')

# %%
positions_df
# Out:
#    position_id      symbol  quantity  average_price  current_price  \
# 0           32  ADANIPORTS         5      89.430032      89.421090
# 1           33  ASIANPAINT        -5     115.401686     115.413228
#
#     stop_loss  take_profit     strategy_id opened_at  \
# 0   87.632668    92.103723  RSI_ADANIPORTS      None
# 1  117.721492   111.950831  RSI_ASIANPAINT      None
#
#                  last_updated
# 0  2025-11-08T22:26:01.785092
# 1  2025-11-08T22:26:16.914090

# %%
fills_df.shape
# Out:
# (60, 8)

# %%
daily_df.tail()
# Out:
#    id        date  opening_equity  closing_equity    high_equity  \
# 0  60  2025-11-08    99655.326103   100103.133657  101219.948891
#
#      low_equity  realized_pnl  unrealized_pnl   total_pnl  commissions  \
# 0  99655.326103     98.563603        4.570054  103.133657     35.87628
#
#    trades_count  winning_trades  losing_trades  max_drawdown    peak_equity  \
# 0            34               5             12   1121.322164  101219.948891
#
#    win_rate
# 0  0.147059

# %%
portfolio_df.tail(1) ## portfolio_overview
# Out:
#       id                   timestamp           cash   total_equity  \
# 119  120  2025-11-08T22:26:17.397090  101605.000106  100103.133657
#
#        total_value  total_realized_pnl  total_unrealized_pnl   total_pnl  \
# 119  101479.711888           98.563603              4.570054  103.133657
#
#      total_commission     exposure  initial_capital
# 119          35.87628  1028.844059         100000.0

# %%
orders_df.columns ## all trades
# Out:
# Index(['order_id', 'symbol', 'side', 'quantity', 'order_type', 'price',
#        'stop_price', 'status', 'filled_quantity', 'average_price', 'timestamp',
#        'strategy_id', 'stop_loss', 'take_profit', 'created_at'],
#       dtype='object')

# %%
# trade_logs_df
# Out:
#     trade_id                              order_id      symbol  \
# 0          1  882e7b5c-dbad-4fa0-9249-5ef42ca7647d         TCS
# 1          2  e6a26f30-6835-472e-a882-5ffa438e0ae5        INFY
# 2          3  15c6fbb9-4592-4c65-96c8-1ba0381baa26        INFY
# 3          4  2948b7ad-d9b1-4c3a-8ecf-9af52ad54800    RELIANCE
# 4          5  6b95dc20-244e-4de2-9150-c51f390458bd         TCS
# 5          6  261aedbc-c44b-4ee4-b912-50c4ba6afeca        INFY
# 6          7  a70d9ef8-6c84-45e4-8f70-5cde244ae0aa         TCS
# 7          8  822daec5-fcac-41f0-ae06-645b698a5aa5    ADANIENT
# 8          9  fd38afc2-5dda-4260-900e-af5075ab2ce9  ADANIPORTS
# 9         10  cf915ddb-d4f8-496b-b93b-a0608eac96a4    ADANIENT
# 10        11  55d6c70a-369e-4136-ac7b-cc328d612993  ASIANPAINT
# 11        12  a6c197a1-e87e-4917-8121-e49c4ba22363  ADANIPORTS
# 12        13  57a372c8-252f-4971-8fde-b070eb95f85f   ICICIBANK
# 13        14  80868342-3350-4819-a7c8-1cdd00efae1c    ADANIENT
# 14        15  32e3ead2-6cf4-4145-b840-43faea4005da    RELIANCE
# 15        16  733c4869-6511-4adb-abe1-de6365ad0531   ICICIBANK
# 16        17  45bae2c7-4016-4c7d-9c61-7a5cd5e649fa  ASIANPAINT
# 17        18  7a77b0bb-5a83-4674-969b-de1b4b305639    ADANIENT
# 18        19  94f4aa7e-a140-46c7-b156-1345c3467cb7  ASIANPAINT
# 19        20  7da6d75a-5231-413d-923a-76afc32a8708  ADANIPORTS
# 20        21  bee76865-d097-4825-9bab-b42fefd5adbb   ICICIBANK
# 21        22  aa6c4e8a-c2af-4fa3-8fc1-45d962f63d62  ASIANPAINT
# 22        23  2cd37520-00e1-494e-988c-4af5624571a9  ASIANPAINT
# 23        24  665659a5-7bf0-4b79-b4b2-b58f9d05e2f1    RELIANCE
# 24        25  b09b0bd6-6152-4129-8dc9-820d2a99ea47    ADANIENT
# 25        26  1028ad6f-0b13-4f85-a851-88a5cf25ef5a  ADANIPORTS
# 26        27  0e128003-98f4-4fc0-9c6a-9da99289227d  ASIANPAINT
#
#           strategy_id trade_type  status                  entry_time  \
# 0             RSI_TCS      SHORT  closed  2025-11-08T21:50:45.081990
# 1            RSI_INFY       LONG  closed  2025-11-08T21:51:15.396329
# 2            RSI_INFY       LONG  closed  2025-11-08T21:52:15.212974
# 3        RSI_RELIANCE       LONG  closed  2025-11-08T21:52:45.368587
# 4        MA_CROSS_TCS      SHORT  closed  2025-11-08T21:52:45.521356
# 5       MA_CROSS_INFY       LONG  closed  2025-11-08T21:54:01.371609
# 6             RSI_TCS       LONG  closed  2025-11-08T21:54:31.625990
# 7        RSI_ADANIENT       LONG  closed  2025-11-08T22:19:29.006534
# 8      RSI_ADANIPORTS       LONG  closed  2025-11-08T22:19:44.164252
# 9        RSI_ADANIENT       LONG  closed  2025-11-08T22:20:14.477223
# 10     RSI_ASIANPAINT      SHORT  closed  2025-11-08T22:23:30.047455
# 11     RSI_ADANIPORTS       LONG  closed  2025-11-08T22:23:30.182321
# 12      RSI_ICICIBANK      SHORT  closed  2025-11-08T22:23:30.317748
# 13       RSI_ADANIENT      SHORT  closed  2025-11-08T22:23:30.457855
# 14       RSI_RELIANCE      SHORT  closed  2025-11-08T22:24:00.265920
# 15      RSI_ICICIBANK      SHORT  closed  2025-11-08T22:24:00.410657
# 16     RSI_ASIANPAINT      SHORT  closed  2025-11-08T22:24:45.670473
# 17       RSI_ADANIENT      SHORT  closed  2025-11-08T22:24:46.495816
# 18     RSI_ASIANPAINT      SHORT  closed  2025-11-08T22:25:15.957443
# 19     RSI_ADANIPORTS       LONG  closed  2025-11-08T22:25:16.791603
# 20      RSI_ICICIBANK      SHORT  closed  2025-11-08T22:25:16.934711
# 21     RSI_ASIANPAINT      SHORT  closed  2025-11-08T22:25:31.596365
# 22     RSI_ASIANPAINT      SHORT  closed  2025-11-08T22:25:47.078590
# 23  MA_CROSS_RELIANCE      SHORT  closed  2025-11-08T22:25:47.221850
# 24       RSI_ADANIENT      SHORT  closed  2025-11-08T22:25:47.538439
