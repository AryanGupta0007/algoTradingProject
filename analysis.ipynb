# %%
import sqlite3
import pandas as pd

# Connect to the SQLite database
conn = sqlite3.connect("trading.db")

# Read the tables into pandas DataFrames
orders_df = pd.read_sql("SELECT * FROM orders", conn)
positions_df = pd.read_sql("SELECT * FROM positions", conn)
fills_df = pd.read_sql("SELECT * FROM fills", conn)
portfolio_df = pd.read_sql("SELECT * FROM portfolio_state", conn)
daily_df = pd.read_sql("SELECT * FROM daily_metrics", conn)
metrics_df = pd.read_sql("SELECT * FROM strategy_metrics", conn)
trade_logs_df = pd.read_sql("SELECT * FROM trades", conn)
market_df = pd.read_sql("SELECT * FROM market_data", conn)


# Close the connection
conn.close()

# %%
orders_df.columns
# Out:
# Index(['order_id', 'symbol', 'side', 'quantity', 'order_type', 'price',
#        'stop_price', 'status', 'filled_quantity', 'average_price', 'timestamp',
#        'strategy_id', 'stop_loss', 'take_profit', 'created_at'],
#       dtype='object')

# %%
positions_df.shape
# Out:
# (25, 10)

# %%
fills_df.shape
# Out:
# (686, 8)

# %%
daily_df.tail()
# Out:
#     id        date  opening_equity  closing_equity    high_equity  \
# 0  686  2025-11-09   139595.326854   133936.985483  146507.406439
#
#       low_equity  realized_pnl  unrealized_pnl     total_pnl  commissions  \
# 0  133919.711443  33905.046624       31.938859  33936.985483   500.665003
#
#    trades_count  winning_trades  losing_trades  max_drawdown    peak_equity  \
# 0             6               3              1  12587.694995  146507.406439
#
#    win_rate
# 0       0.5

# %%
portfolio_df.tail(1) ## portfolio_overview
# Out:
#         id                   timestamp           cash   total_equity  \
# 1371  1372  2025-11-09T22:55:32.604442  127036.222117  133936.985483
#
#         total_value  total_realized_pnl  total_unrealized_pnl     total_pnl  \
# 1371  125476.286821        33905.046624             31.938859  33936.985483
#
#       total_commission     exposure  initial_capital
# 1371        500.665003  1559.935296         100000.0

# %%
orders_df.columns ## all trades
# Out:
# Index(['order_id', 'symbol', 'side', 'quantity', 'order_type', 'price',
#        'stop_price', 'status', 'filled_quantity', 'average_price', 'timestamp',
#        'strategy_id', 'stop_loss', 'take_profit', 'created_at'],
#       dtype='object')

# %%
trade_logs_df.strategy_id.unique()
# Out:
# array(['RSI_ADANIPORTS', 'RSI_ICICIBANK', 'RSI_RELIANCE', 'ORB_ADANIENT',
#        'ORB_ADANIPORTS', 'ORB_ASIANPAINT', 'ORB_ICICIBANK',
#        'MA_CROSS_RELIANCE', 'RSI_ASIANPAINT', 'MA_CROSS_ADANIPORTS',
#        'ORB_RELIANCE', 'ADX_ST_ADANIPORTS', 'ADX_SIG_ICICIBANK',
#        'MA_CROSS_ICICIBANK', 'EMA_X_ADANIPORTS', 'RSI_ADANIENT',
#        'ADX_ST_ADANIENT', 'ADX_SIG_ADANIENT', 'ADX_SIG_RELIANCE',
#        'ADX_ST_ASIANPAINT', 'EMA_X_ICICIBANK', 'ADX_SIG_ASIANPAINT'],
#       dtype=object)

# %%
# trade_logs_df[trade_logs_df['strategy_id'] == 'ORB_ADANIPORTS']
# df = trade_logs_df[trade_logs_df['status'] == 'closed']
# df[df['strategy_id'] == 'RSI_ADANIENT']

# %%
positions_df[positions_df['strategy_id'] == 'RSI_ADANIENT']
# Out:
#     position_id    symbol  quantity  average_price  current_price   stop_loss  \
# 24          565  ADANIENT       -10     104.939605     103.481363  108.547213
#
#     take_profit   strategy_id                   opened_at  \
# 24   103.226271  RSI_ADANIENT  2025-11-09T13:46:41.423246
#
#                   last_updated
# 24  2025-11-09T22:55:31.988428

# %%
market_df['timestamp'] = pd.to_datetime(market_df['timestamp'], format='mixed')
market_df.sort_values('timestamp', inplace=True, ascending=True)
market_df.set_index('timestamp', inplace=True)
market_df[market_df['symbol'] == 'RELIANCE']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[528], line 1
# ----> 1 market_df['timestamp'] = pd.to_datetime(market_df['timestamp'])
#       2 market_df.sort_values('timestamp', inplace=True, ascending=True)
#       3 market_df.set_index('timestamp', inplace=True)
#
# File c:\Users\aryan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     if not cache_array.empty:
#    1065         result = arg.map(cache_array)
#
# File c:\Users\aryan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:247, in _maybe_cache(arg, format, cache, convert_listlike)
#     245 unique_dates = unique(arg)
#     246 if len(unique_dates) < len(arg):
# --> 247     cache_dates = convert_listlike(unique_dates, format)
#     248     # GH#45319
#     249     try:
#
# File c:\Users\aryan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     431 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     432 if format is not None and format != "mixed":
# --> 433     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     435 result, tz_parsed = objects_to_datetime64(
#     436     arg,
#     437     dayfirst=dayfirst,
#    (...)
#     441     allow_object=True,
#     442 )
#     444 if tz_parsed is not None:
#     445     # We can take a shortcut since the datetime64 numpy array
#     446     # is in UTC
#
# File c:\Users\aryan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:467, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     456 def _array_strptime_with_fallback(
#     457     arg,
#     458     name,
#    (...)
#     462     errors: str,
#     463 ) -> Index:
#     464     """
#     465     Call array_strptime, with fallback behavior depending on 'errors'.
#     466     """
# --> 467     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     468     if tz_out is not None:
#     469         unit = np.datetime_data(result.dtype)[0]
#
# File strptime.pyx:501, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:451, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:583, in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "2025-11-07T15:00:00" doesn't match format "%Y-%m-%dT%H:%M:%S.%f", at position 871. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
positions_df['opened_at'] = pd.to_datetime(positions_df['opened_at'])
positions_df['last_updated'] = pd.to_datetime(positions_df['last_updated'])
positions_df.sort_values('opened_at', inplace=True, ascending=False)
positions_df[['opened_at', 'strategy_id', 'average_price']].head(2)
# Out:
#   opened_at        strategy_id  average_price
# 0       NaT  ADX_ST_ADANIPORTS     100.240724
# 1       NaT     EMA_X_ADANIENT      86.400017

# %%
positions_df.columns
# Out:
# Index(['position_id', 'symbol', 'quantity', 'average_price', 'current_price',
#        'stop_loss', 'take_profit', 'strategy_id', 'opened_at', 'last_updated'],
#       dtype='object')

# %%
trade_logs_df['entry_time'] = pd.to_datetime(trade_logs_df['entry_time'])
trade_logs_df['exit_time'] = pd.to_datetime(trade_logs_df['exit_time'])
trade_logs_df.sort_values(by='entry_time', inplace=True, ascending=False)

# %%
trade_logs_df[['entry_time', 'exit_time', 'strategy_id', 'trade_type', 'status']].head()
# Out:
#                     entry_time exit_time          strategy_id trade_type  \
# 118 2025-11-09 13:58:10.726380       NaT  MA_CROSS_ADANIPORTS       LONG
# 117 2025-11-09 13:57:17.952135       NaT       ORB_ASIANPAINT      SHORT
# 116 2025-11-09 13:57:08.046999       NaT        ORB_ICICIBANK       LONG
# 115 2025-11-09 13:57:07.721516       NaT       ORB_ASIANPAINT       LONG
# 114 2025-11-09 13:57:07.069013       NaT       RSI_ASIANPAINT       LONG
#
#     status
# 118   open
# 117   open
# 116   open
# 115   open
# 114   open

# %%
adaniports_df = market_df[market_df['symbol'] == 'ADANIPORTS']

# %%
import numpy as np
adaniports_df['SMA_10'] = adaniports_df['close'].rolling(window=10).mean()
adaniports_df['SMA_30'] = adaniports_df['close'].rolling(window=30).mean()

adaniports_df['Signal'] = np.where(adaniports_df['SMA_10'] > adaniports_df['SMA_30'], 1, 0)
# Out:
# C:\Users\aryan\AppData\Local\Temp\ipykernel_4564\2659707378.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adaniports_df['SMA_10'] = adaniports_df['close'].rolling(window=10).mean()
# C:\Users\aryan\AppData\Local\Temp\ipykernel_4564\2659707378.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adaniports_df['SMA_30'] = adaniports_df['close'].rolling(window=30).mean()
# C:\Users\aryan\AppData\Local\Temp\ipykernel_4564\2659707378.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adaniports_df['Signal'] = np.where(adaniports_df['SMA_10'] > adaniports_df['SMA_30'], 1, 0)

# %%
adaniports_df.tail(5)
# Out:
#                               id      symbol        open        high  \
# timestamp
# 2025-11-09 13:57:48.100098  1451  ADANIPORTS  104.324168  108.452052
# 2025-11-09 13:57:58.943874  1461  ADANIPORTS  107.308629  108.193710
# 2025-11-09 13:58:09.807969  1471  ADANIPORTS  105.948146  106.724916
# 2025-11-09 13:58:20.550059  1481  ADANIPORTS  105.307597  107.051933
# 2025-11-09 13:58:31.321010  1491  ADANIPORTS  106.992423  107.203191
#
#                                    low       close  volume      SMA_10  \
# timestamp
# 2025-11-09 13:57:48.100098  103.745969  107.308629    8569  105.037006
# 2025-11-09 13:57:58.943874  105.854639  105.948146    5804  105.534212
# 2025-11-09 13:58:09.807969  105.240349  105.307597    1389  105.657718
# 2025-11-09 13:58:20.550059  104.809024  106.992423    1309  105.810893
# 2025-11-09 13:58:31.321010  106.302213  106.899931    8067  105.751166
#
#                                 SMA_30  Signal
# timestamp
# 2025-11-09 13:57:48.100098  103.941853       1
# 2025-11-09 13:57:58.943874  104.179554       1
# 2025-11-09 13:58:09.807969  104.390059       1
# 2025-11-09 13:58:20.550059  104.644304       1
# 2025-11-09 13:58:31.321010  104.744006       1

# %%
trade_logs_df.columns
# Out:
# Index(['trade_id', 'order_id', 'symbol', 'strategy_id', 'trade_type', 'status',
#        'entry_time', 'entry_price', 'exit_time', 'exit_price', 'stop_loss',
#        'take_profit', 'ltp'],
#       dtype='object')

# %%
trade_logs_df[(trade_logs_df['strategy_id'] == 'MA_CROSS_ADANIPORTS')]
# Out:
#      trade_id                              order_id      symbol  \
# 118       119  9be3583f-3257-4e41-a409-a740c3531307  ADANIPORTS
# 14         15  ae2f904b-9abe-443c-9c34-cb34b5fe75f8  ADANIPORTS
#
#              strategy_id trade_type status                 entry_time  \
# 118  MA_CROSS_ADANIPORTS       LONG   open 2025-11-09 13:58:10.726380
# 14   MA_CROSS_ADANIPORTS       LONG   open 2025-11-09 13:38:22.567566
#
#      entry_price exit_time  exit_price   stop_loss  take_profit         ltp
# 118   105.318128       NaT         NaN  103.201445   109.519901  106.899931
# 14     96.234396       NaT         NaN   94.300278   100.073765  106.899931
